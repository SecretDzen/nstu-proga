# %% [markdown]
# # Лабораторная работа #2

# %% [markdown]
# - **Материалы для ЛР расположены в гугл-папке [чтение по ссылке]:
# “СИИиМО-2023.09 Бакалавры”, URL:** [**https://clck.ru/35ZXR8**](https://clck.ru/35ZXR8)
#
# - **Ссылка на вебинар с разбором хода работы ЛР2 и комментариями, URL:**
# [**https://bbb-records.edu.nstu.ru/playback/presentation/2.3/697c74b843924b91995df01475316a80783ec31b-1666318636681**](https://bbb-records.edu.nstu.ru/playback/presentation/2.3/697c74b843924b91995df01475316a80783ec31b-1666318636681)

# %% [markdown]
# ## Цель работы
#
# Знакомство и освоение работы с дополнительными методами машинного обучения для решения задачи регрессии библиотеки sklearn.

# %% [markdown]
# ## Ход работы
# Ознакомиться с методическими материалами и примерами выполнения команд.
# Последовательно выполнить следующие шаги применительно к выборке данных, согласно варианту задания:
#
# 1. Загрузка данных
#
#     1. Выполнить загрузку файла с подготовленным набором данных (отчищенный от пропусков и выбросов для целевой и независимых переменных) в таблицу _df_
#
#     2. Объявить список независимых и целевой переменных
#
#     3. Оставить в таблице данных _df_ столбцы, относящиеся только к списку независимых и целевой переменных
#
#
#
# 2. Выполнить процедуры стандартизации каждого признака (столбца) и сохранить в отдельную таблицу _df_scaled_
#
#     1. Получите величину среднего значения и среднеквадратического отклонения для целевой переменной
#
#     2. Для целевой переменной построить гистограммы распределения стандартизированых и  исходных значений
#
#
# 3. Разделите каждую из таблиц _df_ и _df_scaled_ на обучающую и проверочную части:
#
#     1. Выберите значение для начального состояния генератора случайных чисел (ГСЧ)
#
#     2. Получите результат разделения таблицы _df_ (НЕ стандартизированная выборка): _x__train_ , _x__test_ , _y__train_ , _y__test_
#     2. Получите результат разделения таблицы _df_scaled_ (Стандартизированная выборка): _xStd__train_ , _xStd__test_ , _yStd__train_ , _yStd__test_
#
#
# 4. Построить две модели методом SGDRegressor: на НЕ стандартизированных  (m1) и на стандартизированных (m2) данных. Для каждой из моделей m1, m2:
#
#     1. Получить метрики RMSE, R2
#
#     2. Построить диаграмму рассеяния вычисленных значений от проверочных значений
#
#     3. Построить гистограмму остатков (разностей между вычисленными и проверочными)
#
#
#
# 5. Вернитесь к части соответствующей пунктку 3.1 и измените значение для начального состояния генератора случайных чисел (ГСЧ). Повторите разделение и вычисления соостветсвующие п. 3.2, 3.3, 4.1 - 4.4 хода работы
#
# 6. Сравнить полученные результаты и сделать заключение о:
#     - Влияние операции стандартизации на точность моделей (изменение R^2 и RMSE у моделей m1 и m2)
#     - Влияние перемешивания при разделении (изменение R^2 и RMSE при различных rand_seed),
#
# 5. Используя модель SGDRegressor и прием кросс-валидации получить на проверочной части (*_test) НЕ стандартизированных и стандартизированных данных следующие оценки точности:
#
#     1. R2(коэфф. детерминации)
#
#     2. RMSE (среднеквадратичное отклонение)
#
#
# |Оценка|на станд.| на НЕ станд.|
# |-|-|-|
# |Разделений|k=...|
# |R2|[r2Std_1, r2Std_2, ...]|[r2_1, r2_2, ...]|
# |R2 средн| 0.xx|0.xx|
# |RMSE|[rmseStd_1, rmseStd_2, ...]|[rmse_1, rmse_2, ...]|
# |RMSE средн|x.xx|x.xx|
#
# 6. Провести сравнение полученных значений и сделать заключение о велечине коридора изменений оценок моделей

# %% [markdown]
# ## Содержание отчета
# <font color='red'>Название отчета должно быть в формате:
# <br>АВТ-9xx_ЛР-xx_Фамилия1_Фамилия2.ipynb
# </font>
#
#
# 1. Список выбранных  целевой переменной 'y' и независимых признаков 'x1, x2, x3, ...',
# 2. Описание процесса загрузки и стандартизации с выводом значений таблиц
# 3. Гистограммы распределения исходных и стандартизированных значений для  целевой переменной 'y' и независимых признаков
# 4. Результаты построения, оценки и сравнения моделей SGDRegressor:
#     1. Значения точности R2 и RMSE
#     2. Диаграмма рассеяния вычисленных значений Y_pred от проверочных значений Y_test
#     3. Гистограмму остатков (разностей между Y_pred и Y_test)
#
# 5. Оценки точности полученные приемом кросс-валидации на проверочных частях выборки.
# 6. Выводы по результатам сравнительного анализа полученных регрессионных моделей

# %% [markdown]
# ## Список литературы и доп. материалы:
#
#
# Список материалов:
#
# 1. [Рус] Дьяконов А. Ансамбли в машинном обучении. URL:
# https://dyakonov.org/2019/04/19/%D0%B0%D0%BD%D1%81%D0%B0%D0%BC%D0%B1%D0%BB%D0%B8-%D0%B2-%D0%BC%D0%B0%D1%88%D0%B8%D0%BD%D0%BD%D0%BE%D0%BC-%D0%BE%D0%B1%D1%83%D1%87%D0%B5%D0%BD%D0%B8%D0%B8/
#
# 2. Scikit-learn. стохастический градиентный спуск
#
#     2.1 [Eng] Scikit-learn. Класс стохастического градиентного спуска. URL: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDRegressor.html
#
#     2.2 [Eng] Scikit-learn. Класс стохастического градиентного спуска. URL: https://scikit-learn.org/stable/modules/sgd.html#regression
#
# 3. Стандартизация
#
#     3.1. [Eng] Scikit-learn. Стандартизация. URL: https://scikit-learn.org/stable/modules/preprocessing.html#standardization-or-mean-removal-and-variance-scaling
#
#     3.2. [Eng] Scikit-learn. Сравнение влияния различных шкал на данные в выбросами. URL: https://scikit-learn.org/stable/auto_examples/preprocessing/plot_all_scaling.html
#
#
# 4. [Рус] Мюллер А., Гвидо С. Введение в машинное обучение с помощью Python //Руководство для специалистов по работе с данными. СПб.: ООО «Альфа-книга. – 2017. –  с. 269 (Перекрестная проверка)

# %% [markdown]
# - - -

# %% [markdown]
# # Подключение библиотек

# %% [markdown]
# Перед началом работы убедитесь, что необходимые для работы пакеты установлены в системе. Для установки отсутствующих используйте соответствующую команду:
# ```
# > …Путь_к_Python\python -m pip install --upgrade pip
# > …Путь_к_Python\Scripts\pip3  install jupyterlab
# > …Путь_к_Python\Scripts\pip3  install pandas  numpy  scikit-learn
# > …Путь_к_Python\Scripts\pip3  install plotly seaborn matplotlib
# > …Путь_к_Python\Scripts\pip3  install tensorflow  streamlit
# ```
#
# Назначение библиотек:
# * numpy - обработка многомерных массивов, линейная алгебра, преобразование Фурье, случайные числа
# * pandas - обработка (загрузка, сохранение, анализа) данных
# * seaborn - визуализация данных (на базе matplotlib)
# * sklearn - алгоритмы машинного обучения(классификация, регрессия, кластеризация...)
# * scipy - пакет для выполнения научных и инженерных расчётов.

# %%
# Python 3.8
import pandas as pd
import numpy  as np

import sklearn
from sklearn import linear_model
from sklearn import ensemble
from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler

# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import cm
import seaborn as sns

# %%
# Проверка версий библиотек
for lib in [pd, np, sklearn]:
    print(f"{lib.__name__:<12} {lib.__version__}")

# Проверка версии и пути к выбранному интерпретатору
import sys
print(f"Версия Python - {sys.version}")
print(f"Путь к интерпретатору Python - {sys.executable}")
# Out:
# pandas       1.5.3
# numpy        1.26.0
# sklearn      1.3.1
# Версия Python - 3.11.5 (main, Sep  2 2023, 14:16:33) [GCC 13.2.1 20230801]
# Путь к интерпретатору Python - /usr/bin/python

# %% [markdown]
# # Объявление функций
#
# Для повышения повторяемости кода и повышения уровня читаемости объявим несколько функций с уже знакомыми операциями

# %%
def PLOT34(y_test, y_pred):
    '''
    Функция построения графиков
    :param y_test: - проверочные значения целевой переменный
    :param y_pred: - вычисленные значения целевой переменный
    '''
    plt.figure(figsize=(12,6))

    # == Диаграмма рассеяния вычисленных значений ==
    # создать первое полотно 121: 1-строк, 2-столбцов, 1-индекс текущего полотна в сетке
    plt.subplot(121)
    plt.scatter(y_test, y_pred,  alpha=0.1)
    plt.scatter(y_test, y_test,  alpha=0.1)
    plt.title('Диаграмма рассеяния вычисленных значений');
    plt.xlabel('Проверочное Y')
    plt.ylabel('Вычисленное Y')


    # == Диаграмма рассеяния ошибок ==
    # создать первое полотно 121: 1-строк, 2-столбцов, 2-индекс текущего полотна в сетке
    plt.subplot(122)
    plt.scatter(y_test, (y_test - y_pred)**2,  alpha=0.1)
    plt.title('Диаграмма рассеяния квадрата абсолютной ошибки')
    plt.xlabel('Проверочное Y')
    plt.ylabel('Квадрат абсолютной ошибки')
#--------------------------------------------------------------------------

# %%
def GET_METRICS_SINGLE(y_test, y_pred):
    '''
    Вычисление и вывод метрик: MAE, RMSE, R2.
    На основе сравнения проверочных и вычисленных.
    :param y_test: - проверочные значения целевой переменный
    :param y_pred: - вычисленные значения целевой переменный
    '''
    mae  = metrics.mean_absolute_error        (y_test, y_pred)
    mse  = metrics.mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2   = metrics.r2_score                   (y_test, y_pred)

    print ("MAE : {:>9,.3f} (средняя абсолютная ошибка)".format              ( mae ))
    print ("MSE : {:>9,.6f} (среднеквадратичная ошибка)".format( mse ))
    print ("RMSE: {:>9,.6f} (кв. корень из среднеквадратичной ошибки)".format( rmse ))
    print ("R2  : {:>9,.3f} (коэфф. детерминации)".format                    ( r2 ))
#--------------------------------------------------------------------------

# %%
def FORM_TRAIN(rand_seed, valid_size, dataX, dataY):
    return train_test_split(
        dataX,                  # исходные данные X
        dataY,                  # исходные данные y
        test_size = valid_size, # доля тестовой части в выборке
        random_state=rand_seed, # начальное состояние генератора случ. чисел
        shuffle=True            # перемешивание
    )

# %% [markdown]
# - - -

# %% [markdown]
# # Загрузка подготовленных данных

# %% [markdown]
# <b> Путь вида "./datasets/melbourne_data_PREPARED.csv" подразумевает следующее расположение файлов:
# ```
# WorkDir/
# ├─ datasets/
# │  └─ melbourne_data_PREPARED.csv
# ├─ 2.ЛР-2.ipynb
# ```
# </b>

# %% [markdown]
# Для сохранения данных в ЛР-1,2 используйте команду
# ```
#    data.to_csv('./путь/имя_файла.csv', index=False), где:
#      './путь/имя_файла.csv' - абсолютный или относительный путь к новому файлу;
#      index=False - значение параметра для исключения столбца с идентификаторами.
# ```

# %%
df = pd.read_csv('./dataset/new_dataset.csv', sep=',', header=0)
print("Размер таблицы", df.shape)
df[:2]
# Out:
# Размер таблицы (16489, 17)
#     id  season  year  month  hour  isHoliday  isWeekday  isWorkingDay  \
# 0  1.0     1.0   0.0    1.0   0.0        0.0        6.0           0.0
# 1  2.0     1.0   0.0    1.0   1.0        0.0        6.0           0.0
#
#    weatherStatus  temp  temp_f  humidity  windSpeed  casualUsers  \
# 0            1.0  0.24  0.2879      0.81        0.0          3.0
# 1            1.0  0.22  0.2727      0.80        0.0          8.0
#
#    registeredusers  count  dateDay
# 0             13.0   16.0      1.0
# 1             32.0   40.0      1.0

# %% [markdown]
# Для начала определим точный список признаков с целевой и независимыми признаками, а после оставим в таблице только перечисленные столбцы.

# %%
features = ['season', 'year', 'month', 'hour', 'isHoliday', 'isWeekday', 'temp', 'temp_f', 'humidity',  'windSpeed', 'weatherStatus']
target   = ['count']

# %% [markdown]
# Для выполнения следующих шагов разделим исходую таблицу на две отдельных
#   - dfX содержащую только объясняющие признаки
#   - dfY содержащую только целевой объясняемый признак

# %%
dfX = df[features]
print("Размер таблицы", dfX.shape)
dfX[:2]
# Out:
# Размер таблицы (16489, 11)
#    season  year  month  hour  isHoliday  isWeekday  temp  temp_f  humidity  \
# 0     1.0   0.0    1.0   0.0        0.0        6.0  0.24  0.2879      0.81
# 1     1.0   0.0    1.0   1.0        0.0        6.0  0.22  0.2727      0.80
#
#    windSpeed  weatherStatus
# 0        0.0            1.0
# 1        0.0            1.0

# %% [markdown]
# ## Денормализация данных

# %% [markdown]
# Так как исходная таблица содержит данные, которые уже нормализованы и приведены к диапазону от 0 до 1, нам потребуется изменить их

# %%
df_non_std = df

df_non_std['hour'] *= 60

df_non_std['temp'] *= 40
df_non_std['temp'] -= 20
df_non_std['temp'] *= 1000

df_non_std['humidity'] *= 133

# %%
df_non_std[:2]
# Out:
#     id  season  year  month  hour  isHoliday  isWeekday  isWorkingDay  \
# 0  1.0     1.0   0.0    1.0   0.0        0.0        6.0           0.0
# 1  2.0     1.0   0.0    1.0  60.0        0.0        6.0           0.0
#
#    weatherStatus     temp  temp_f  humidity  windSpeed  casualUsers  \
# 0            1.0 -10400.0  0.2879    107.73        0.0          3.0
# 1            1.0 -11200.0  0.2727    106.40        0.0          8.0
#
#    registeredusers  count  dateDay
# 0             13.0   16.0      1.0
# 1             32.0   40.0      1.0

# %%
dfY = df[target]
print("Размер таблицы", dfY.shape)
dfY[:2]
# Out:
# Размер таблицы (16489, 1)
#    count
# 0   16.0
# 1   40.0

# %% [markdown]
# # Приведение к новой шкале значений

# %% [markdown]
# Важнейшими числовыми характеристиками случайной величины являются:
#
# - Математическое ожидание, имеющее смысл среднего значения  (mean)  $ {\\mu} $ (мю) - центр распределения случайной величины
#       .mean()
#
# - Среднеквадратическое отклонение (Standard_deviation) $ {\\sigma} $ (сигма) - показатель рассеивания относительно её мат. ожидания.
#       .std()
#
# - Дисперсия (Variance) $ {\\var = sigma^2} $ (сигма в квадрате) - мера разброса относительно её мат. ожидания.
#       .var  =  .std()**2

# %% [markdown]
# Некоторые методы машинного обучения
# сильно чувствительны к шкалированию данных.
#
# При подготовки данных чаще всего выполняются процедуры:
#
# - либо __нормализации__  -  приведения значений к диапазону от 0.0 до 1.0 Пример:
#
#       |--------------|+++++++++|----|
#       |--------------|++++++++++++++|
#       0             1900     1970  2000
#
#       Обрабатываемое: 1970
#       Макс. значение: 1900
#       Мин. значение:  2000
#
#       Процедура нормализации:
#       x_norm = ( x - X.min() ) / ( X.max() -  X.min() )
#       x_norm = ( 1970 - 1900 ) / (2000 - 1900)
#       x_norm = 70 / 100
#       x_norm = 0.70
#
#       Восстановление:
#       x = ( x_norm * ( X.max() -  X.min() ) +  X.min()
#       x = ( 0.70 * (2000 - 1900) + 1900
#       x = ( 0.70 * 100) + 1900
#       x = 70 + 1900
#       x = 1970

# %% [markdown]
# - либо __стандартизации__ - предобработки данных, после которой каждый признак имеет среднее (mean) = 0 и дисперсию (variance) = 1. Стандартизовать - вычесть среднее и поделить на стандартное отклонение. Критично для линейных моделей.
#       X_stantartised = (X - X.mean()) / X.std()
#
# ![std.png](data:image/png;base64,...)
# <p style="text-align: right;"> Рис. 1. Вид гистограмм до и после стандартизации </p>
#
# "Одно из наиболее важных допущений при работе с линейными моделями, параметры которых оцениваются методом наименьших квадратов, состоит в том, что остатки модели независимы (т.е. не коррелируют) и имеют нормальное распределение со средним значением 0 и некоторым фиксированным стандартным отклонением"

# %%
# Пример операции стандартизации
df_ex1 = pd.DataFrame(
  np.array([1900,1920,1920,1940,1940,1940,1950,1950,1950,1950,1950,1950,1970,1970,1970,2000 # последовательность
  ]),
  columns=["Year"]
)

print ("Среднекв. откл. (Stand._dev.)", df_ex1.std(ddof=0)[0])
print ("Дисперсия (Variance) ", df_ex1.var(ddof=0)[0])
print ("Средрее (Mean)", df_ex1.mean()[0])

# X_stantartised = (X - X.mean()) / X.std()
df_Std = (df_ex1 - df_ex1.mean())/df_ex1.std(ddof=0)

plt.figure(figsize=(10,5))
plt.subplot(121)
plt.hist(df_ex1["Year"])
plt.subplot(122)
plt.hist(df_Std["Year"]);
# Out:
# Среднекв. откл. (Stand._dev.) 22.698774746668597
# Дисперсия (Variance)  515.234375
# Средрее (Mean) 1948.125

# %% [markdown]
# - - -

# %% [markdown]
# Для дальнейшей работы рассмотрим способы выполнения операции стандартизации

# %% [markdown]
# ## Стандартизация. Способ #1

# %% [markdown]
# Благодаря наличию функций вычисления статистических характеристик в библиотеке pandas, стандартизацию можно выполнить прямом вычислением.

# %%
dfX_scaled = (dfX - dfX.mean()) / dfX.std(ddof=0) # обязательный параметр ddof=0
dfX_scaled[:2]
# Out:
#      season      year     month      hour  isHoliday  isWeekday      temp  \
# 0 -1.358006 -0.987284 -1.608791 -1.647919  -0.175005   1.494905 -1.324068
# 1 -1.358006 -0.987284 -1.608791 -1.504090  -0.175005   1.494905 -1.427952
#
#      temp_f  humidity  windSpeed  weatherStatus
# 0 -1.085976  0.931570  -1.611396      -0.669552
# 1 -1.174563  0.879111  -1.611396      -0.669552

# %%
dfY_scaled = (dfY - dfY.mean()) / dfY.std(ddof=0) # обязательный параметр ddof=0
dfY_scaled[:2]
# Out:
#       count
# 0 -0.998408
# 1 -0.850979

# %% [markdown]
# ## Стандартизация. Способ #2.

# %% [markdown]
# В библиотеке sklearn, для выполнения процедуры стандартизации, присутствует более удобный класс __sklearn.preprocessing.StandardScaler__, который содержит методы:
#
# - __StandardScaler.fit(  X  )__ - вычисление значений __среднего__ и __дисперсии__
#
# - __StandardScaler.transform( X )__ - прямого преобразования из истинного значения к приведенному
#
# - __StandardScaler.inverse_transform( X )__ - обратного преобразования из приведенного значения в истинное

# %%
from sklearn.preprocessing import StandardScaler
scalerStdX = StandardScaler()
scalerStdY = StandardScaler()

# %%
#  вычисление значений среднего и дисперсии отдельно для каждого признака
scalerStdX.fit (dfX)
scalerStdY.fit (dfY)
# Out:
# StandardScaler()

# %%
print (" {:>3} {:<25} {:>16} {:>16}".format(
 "№", "Признак", "Средрее", "Ср.кв.откл."
))

for icol in range (0, len(dfX.columns)):
    print (" {:>3} {:<25} {:>16.3f} {:>16.3f}".format(
                   icol,
                   dfX.columns[icol],
                   scalerStdX.mean_[icol],
                   np.sqrt ( scalerStdX.var_[icol]), # кв. корень (из дисперсии)
                  ))
# Out:
#    № Признак                            Средрее      Ср.кв.откл.
#    0 season                               2.504            1.108
#    1 year                                 0.494            0.500
#    2 month                                6.545            3.446
#    3 hour                                11.457            6.953
#    4 isHoliday                            0.030            0.170
#    5 isWeekday                            2.994            2.011
#    6 temp                                 0.495            0.193
#    7 temp_f                               0.474            0.172
#    8 humidity                             0.632            0.191
#    9 windSpeed                            0.184            0.114
#   10 weatherStatus                        1.427            0.638

# %% [markdown]
# При прямом преобразовании значений (функция transform()) данные возвращаются без информации о принадлежности к строкам и столбцам.

# %%
# Пример для осмотра предварительного результата
scalerStdX.transform(dfX)
# Out:
# array([[-1.35800649, -0.98728443, -1.6087908 , ...,  0.93157031,
#         -1.61139577, -0.6695521 ],
#        [-1.35800649, -0.98728443, -1.6087908 , ...,  0.87911064,
#         -1.61139577, -0.6695521 ],
#        [-1.35800649, -0.98728443, -1.6087908 , ...,  0.87911064,
#         -1.61139577, -0.6695521 ],
#        ...,
#        [-1.35800649,  1.01287934,  1.58294076, ..., -0.17008271,
#         -0.17727901, -0.6695521 ],
#        [-1.35800649,  1.01287934,  1.58294076, ..., -0.37992138,
#         -0.43842451, -0.6695521 ],
#        [-1.35800649,  1.01287934,  1.58294076, ...,  0.09221563,
#         -0.43842451, -0.6695521 ]])

# %% [markdown]
# Для удобства восприятия сформируем новую таблицу (DataFrame) с указанием названий признаков и идентификаторов строк, соответствующих таблице-оригиналу. Сравните значения с таблице в п. 5.1.

# %%
# создать новую таблицу (DataFrame)
# со стандартизированными значениями

dfXStd = pd.DataFrame (
  data    = scalerStdX.transform(dfX), # значения ячеек    <<--
  columns = dfX.columns,           # названия столбцов
  index   = dfX.index              # идентификаторы строк
)
print("Размер таблицы", dfXStd.shape)
dfXStd[:2]
# Out:
# Размер таблицы (16489, 11)
#      season      year     month      hour  isHoliday  isWeekday      temp  \
# 0 -1.358006 -0.987284 -1.608791 -1.647919  -0.175005   1.494905 -1.324068
# 1 -1.358006 -0.987284 -1.608791 -1.504090  -0.175005   1.494905 -1.427952
#
#      temp_f  humidity  windSpeed  weatherStatus
# 0 -1.085976  0.931570  -1.611396      -0.669552
# 1 -1.174563  0.879111  -1.611396      -0.669552

# %%
# создать новую таблицу (DataFrame)
# со стандартизированными значениями

dfYStd = pd.DataFrame (
  data    = scalerStdY.transform(dfY), # значения ячеек    <<--
  columns = dfY.columns,           # названия столбцов
  index   = dfY.index              # идентификаторы строк
)
print("Размер таблицы", dfYStd.shape)
dfYStd[:2]
# Out:
# Размер таблицы (16489, 1)
#       count
# 0 -0.998408
# 1 -0.850979

# %% [markdown]
# Используя класс  __sklearn.preprocessing.StandardScaler__ становится доступна операция обратного предобразования к исходным НЕ стандартизированным значениям. Этот прием пригодится позже при работе с обученной моделью.

# %%
# строка в стандартизированном виде
dfYStd [0:1]
# Out:
#       count
# 0 -0.998408

# %%
# Результат обратного преобразования обернутые в таблицу (DataFrame)
pd.DataFrame (
    scalerStdY.inverse_transform(
        dfYStd [0:1]  ),
    columns = dfY.columns,
)
# Out:
#    count
# 0   16.0

# %% [markdown]
# ## Информация по целевой переменной
# Получите величину среднего значения и дисперсии для целевой переменной

# %%
print("Среднее значение целевой переменной:", dfY.mean())
print("Дисперсия целевой переменной:", dfY.var())
print("Ср. кв. откл. целевой переменной:", dfY.std())
# Out:
# Среднее значение целевой переменной: count    178.531566
# dtype: float64
# Дисперсия целевой переменной: count    26502.448436
# dtype: float64
# Ср. кв. откл. целевой переменной: count    162.795726
# dtype: float64

# %% [markdown]
# Построить гистограммы распределения исходных и стандартизированных значений для целевого признака

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
plt.hist(dfY["count"])

plt.subplot(122)
plt.hist(dfYStd["count"])
# Out:
# (array([5597., 2736., 2398., 1829., 1324.,  948.,  629.,  483.,  324.,
#          221.]),
#  array([-1.09055044, -0.66116496, -0.23177949,  0.19760598,  0.62699145,
#          1.05637692,  1.4857624 ,  1.91514787,  2.34453334,  2.77391881,
#          3.20330428]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# - - -

# %% [markdown]
# # Формирование тренировочной и проверочной выборок

# %% [markdown]
# ##  НЕ Стандартизованные

# %%
x_train, x_test, y_train, y_test = FORM_TRAIN(8, 0.3, df_non_std[features], df[target])

y_train = y_train['count']
y_test = y_test['count']

xx_train, xx_test, yy_train, yy_test = FORM_TRAIN(24, 0.3, df_non_std[features], df[target])
yy_train = yy_train['count']
yy_test = yy_test['count']

print(x_train[:2])
print(xx_train[:2])
# Out:
#       season  year  month    hour  isHoliday  isWeekday    temp  temp_f  \
# 2140     2.0   0.0    4.0     0.0        0.0        6.0 -8000.0  0.2879
# 9914     1.0   1.0    3.0  1380.0        0.0        5.0 -7200.0  0.3030
#
#       humidity  windSpeed  weatherStatus
# 2140    115.71     0.2239            2.0
# 9914     43.89     0.2985            1.0
#       season  year  month   hour  isHoliday  isWeekday     temp  temp_f  \
# 4239     3.0   0.0    7.0  600.0        0.0        5.0   9600.0  0.6970
# 142      1.0   0.0    1.0  420.0        0.0        5.0 -12000.0  0.2121
#
#       humidity  windSpeed  weatherStatus
# 4239     93.10     0.3582            2.0
# 142      91.77     0.1343            1.0

# %%
y_train[:2]
# Out:
# 2140    31.0
# 9914    86.0
# Name: count, dtype: float64

# %%
print ("Кол-во элементов: \n  x_train: {}, y_train {} \n  x_test:  {}, y_test  {} \n  total x: {}, total y {} ".format  (
    len(x_train), len(y_train),
    len(x_test),  len(x_test),
    len(x_train)+len(x_test), len(y_train)+len(x_test),
))
# Out:
# Кол-во элементов:
#   x_train: 11542, y_train 11542
#   x_test:  4947, y_test  4947
#   total x: 16489, total y 16489

# %% [markdown]
# ## Стандартизованные

# %%
xStd_train, xStd_test, yStd_train, yStd_test = FORM_TRAIN(8, 0.3, dfXStd, dfYStd)
xxStd_train, xxStd_test, yyStd_train, yyStd_test = FORM_TRAIN(24, 0.3, dfXStd, dfYStd)

yStd_train = yStd_train['count']
yStd_test = yStd_test['count']

yyStd_train = yyStd_train['count']
yyStd_test = yyStd_test['count']

print(xStd_train[:2])
print(xxStd_train[:2])
# Out:
#         season      year     month      hour  isHoliday  isWeekday      temp  \
# 2140 -0.455278 -0.987284 -0.738319 -1.647919  -0.175005   1.494905 -1.012416
# 9914 -1.358006  1.012879 -1.028476  1.660157  -0.175005   0.997599 -0.908532
#
#         temp_f  humidity  windSpeed  weatherStatus
# 2140 -1.085976  1.246328   0.344139       0.898219
# 9914 -0.997973 -1.586494   0.995692      -0.669552
#         season      year     month      hour  isHoliday  isWeekday      temp  \
# 4239  0.447450 -0.987284  0.132154 -0.209625  -0.175005   0.997599  1.273030
# 142  -1.358006 -0.987284 -1.608791 -0.641113  -0.175005   0.997599 -1.531836
#
#         temp_f  humidity  windSpeed  weatherStatus
# 4239  1.298282  0.354514   1.517110       0.898219
# 142  -1.527743  0.302054  -0.438425      -0.669552

# %%
yStd_train[:2]
# Out:
# 2140   -0.906265
# 9914   -0.568408
# Name: count, dtype: float64

# %% [markdown]
# # Проверка влияния стандартизации

# %% [markdown]
# Для исследования влияния процесса стандартизации используем новый тип модели - __linear_model.SGDRegressor__. Особенности внутреннего устройства рассматривать пока не будем.
#
# В библиотеке sklearn большинство методов обладают единым интерфейсом взаимодействия и содержат методы
# ```
# - model.fit(x_train, y_train) - обучение модели, вычисление коэфф. для входных признаков
#
# - y_pred = model.predict(x_test) - прогноз модели, вычисление откликов
# ```

# %% [markdown]
# ## Модель SGDRegressor. НЕ стандартизованные (rand_seed = 8)

# %%
# 1. Создать объект класса с моделью стохастического градиентного спуска
sgd_reg_nonStd = linear_model.SGDRegressor(
    max_iter=10000,
    tol=1e-3,
    random_state=8,
)

# %%
# 2. Обучим модель (подберем/подогоним параметры модели)  на НЕ СТАНДАРТИЗИРОВАНОМ проверочном наборе
sgd_reg_nonStd.fit(x_train, y_train)
# Out:
# SGDRegressor(max_iter=10000, random_state=8)

# %%
# 3. Получить вычисленные(predicted) зн. на НЕ СТАНДАРТИЗИРОВАНОМ проверочном наборе
y_pred = sgd_reg_nonStd.predict(x_test)
y_pred
# Out:
# array([ 1.00291627e+16,  7.80389391e+15, -2.26944334e+16, ...,
#         2.82408639e+15,  2.03600649e+16, -1.81878576e+16])

# %%
# 4. Построить графики для оценки ошибки (вычисленные от проверочных)
PLOT34(y_test, y_pred)

# %%
# 5. Получить численные оценки ошибки R2, RMSE, ...
GET_METRICS_SINGLE(y_test, y_pred)
# Out:
# MAE : 13,836,877,196,643,310.000 (средняя абсолютная ошибка)
# MSE : 261,816,060,250,922,248,524,894,887,215,104.000000 (среднеквадратичная ошибка)
# RMSE: 16,180,731,140,802,082.000000 (кв. корень из среднеквадратичной ошибки)
# R2  : -9,837,135,584,108,417,061,402,705,920.000 (коэфф. детерминации)

# %% [markdown]
# ## Модель SGDRegressor. Cтандартизованные. (rand_seed = 8)

# %%
# 1. Создать объект класса с моделью стохастического градиентного спуска
sgd_reg_std =   linear_model.SGDRegressor(
    max_iter=10000,
    tol=2e-5,
    alpha=0.0001,
    random_state=8,
)

# %%
# 2. Обучим модель (подберем/подогоним параметры модели)  на СТАНДАРТИЗИРОВАНОМ проверочном наборе
sgd_reg_std.fit(xStd_train, yStd_train)
# Out:
# SGDRegressor(max_iter=10000, random_state=8, tol=2e-05)

# %%
# 3. Получить вычисленные(predicted) зн. на СТАНДАРТИЗИРОВАНОМ проверочном наборе
y_pred_std = sgd_reg_std.predict(xStd_test)
y_pred_std
# Out:
# array([-0.02045342,  0.2518555 ,  0.2851644 , ...,  0.57291164,
#        -0.55949686,  0.98772819])

# %%
# 4. Построить графики для оценки ошибки (вычисленные от проверочных)
PLOT34(yStd_test, y_pred_std)

# %%
# 5. Получить численные оценки ошибки R2, RMSE, ...
GET_METRICS_SINGLE(yStd_test, y_pred_std)
# Out:
# MAE :     0.593 (средняя абсолютная ошибка)
# MSE :  0.609097 (среднеквадратичная ошибка)
# RMSE:  0.780447 (кв. корень из среднеквадратичной ошибки)
# R2  :     0.394 (коэфф. детерминации)

# %% [markdown]
# ## Модель SGDRegressor. НЕ стандартизованные (rand_seed = 24)

# %%
sgd_regg_nonStd = linear_model.SGDRegressor(
    max_iter=10000,
    tol=1e-3,
    random_state=24,
)

sgd_regg_nonStd.fit(xx_train, yy_train)
# Out:
# SGDRegressor(max_iter=10000, random_state=24)

# %%
yy_pred = sgd_regg_nonStd.predict(xx_test)
yy_pred
# Out:
# array([ 5.47694830e+15,  1.50882247e+14, -3.11628495e+15, ...,
#         2.70097231e+15,  1.19841391e+15,  4.59712603e+15])

# %%
PLOT34(yy_test, yy_pred)

# %%
GET_METRICS_SINGLE(yy_test, yy_pred)
# Out:
# MAE : 2,676,777,908,093,118.500 (средняя абсолютная ошибка)
# MSE : 10,230,312,610,481,628,924,477,297,393,664.000000 (среднеквадратичная ошибка)
# RMSE: 3,198,485,987,226,086.000000 (кв. корень из среднеквадратичной ошибки)
# R2  : -386,481,420,112,727,349,431,107,584.000 (коэфф. детерминации)

# %% [markdown]
# ## Модель SGDRegressor. Cтандартизованные. (rand_seed = 24)

# %%
sgd_regg_std = linear_model.SGDRegressor(
    max_iter = 10000,
    tol = 2e-5,
    alpha = 0.0001,
    random_state = 24,
)

# %%
sgd_regg_std.fit(xxStd_train, yyStd_train)
# Out:
# SGDRegressor(max_iter=10000, random_state=24, tol=2e-05)

# %%
yy_pred_std = sgd_regg_std.predict(xxStd_test)
yy_pred_std
# Out:
# array([-0.51016553, -0.19386548,  1.23203895, ...,  0.08998948,
#        -0.21847902,  0.07628275])

# %%
PLOT34(yyStd_test, yy_pred_std)

# %%
GET_METRICS_SINGLE(yyStd_test, yy_pred_std)
# Out:
# MAE :     0.590 (средняя абсолютная ошибка)
# MSE :  0.612843 (среднеквадратичная ошибка)
# RMSE:  0.782843 (кв. корень из среднеквадратичной ошибки)
# R2  :     0.386 (коэфф. детерминации)

# %% [markdown]
# ## Заключение по полученых результатам
# Сравнить полученные результаты и сделать заключение о:
# - Влияние операции стандартизации на точность моделей (изменение R^2 и RMSE у моделей m1 и m2)
#
# - Влияние перемешивания при разделении (изменение R^2 и RMSE при различных rand_seed),

# %%
non_std_results = [['5,265,555,363,547,413.000000', '-1,059,388,994,580,583,412,494,499,840.000'], ['5,780,223,309,704,495.000000', '-1,307,828,716,219,297,966,946,516,992.000']]

# %%
std_results = [['0.803550', '0.363'], ['0.780921', '0.384']]

# %%
print(non_std_results)
print(std_results)
# Out:
# [['5,265,555,363,547,413.000000', '-1,059,388,994,580,583,412,494,499,840.000'], ['5,780,223,309,704,495.000000', '-1,307,828,716,219,297,966,946,516,992.000']]
# [['0.803550', '0.363'], ['0.780921', '0.384']]

# %% [markdown]
# # Кросс-валидация

# %% [markdown]
# В виду того, что при разделении на обучающую и проверочные части используется случайный выбор, оценки точности обученой модели будут напрямую зависеть каждого нового случайного распределения образцов. При этом от случая к случаю оценки точности будут изменятся.
#
#
# Для получения более объективной оценки применяется прием Кросс-валидации (cross-validation) или скользящего контроля — процедура эмпирического оценивания обобщающей способности алгоритмов.
# Обобщающая способность — это способность модели выдавать правильные результаты не только для примеров, участвовавших в процессе обучения, но и для любых новых, проверочных.

# %% [markdown]
# Обучающая (Train) часть выборки разделяется на K-частей, для каждой из которых:
#  - происходит создание и обучение модели на данных не принадлежащих текущей K-части
#  - полученая промежуточная модель получает оценку точности по образцам K-части

# %% [markdown]
# ![CrossVal.png](data:image/png;base64,...)

# %% [markdown]
# В библиотеке sklearn в пакете sklearn.model_selection присоветуют следующие функции
#
# - cross_val_score (estimator, X, y, cv, scoring) - получение единственной метрики
# - cross_validate  (estimator, X, y, cv, scoring) - получение нескольких метрик
# - cross_val_predict(estimator, X, y, cv=3) - получить отклики, вычисленные моделью над набором входных значений
#
# где, scoring - Метрики регрессии имеет режимы:
#   - r2 - коэфф. детерминации (R2)
#   - neg_mean_squared_error - ср. кв. ошибка (MSE)
#   - neg_root_mean_squared_error - кв. корень из ср. кв. ошибки (RMSE)

# %%
modelForCV =  linear_model.SGDRegressor(
    max_iter=100000,
    tol=1e-3,
    random_state=120,
)

# %%
print("R2. НЕ Стандартизированные  проверочные данные")
scores_cross = cross_val_score(
                                    estimator = modelForCV, # Модель для обучения (вызова метода .fit())
                                    X = xx_test,   # Независимые переменные
                                    y = yy_test,   # Целевая переменная
                                    cv = 3,       # Кол-во K-частей (Fold)
                                    scoring = 'r2'# Режим расчитываемой метрики
                                )

print("Значения метрики по каждому блоку cv:", scores_cross)
print("Усредненное значение метрики:", scores_cross.mean())
# Out:
# R2. НЕ Стандартизированные  проверочные данные
# Значения метрики по каждому блоку cv: [-4.30281523e+28 -1.05531382e+26 -2.87893709e+27]
# Усредненное значение метрики: -1.5337540253903487e+28

# %%
print("R2. Стандартизированные проверочные данные")

scores_cross = cross_val_score(
                                    estimator = modelForCV, # Модель для обучения (вызова метода .fit())
                                    X=xxStd_test,   # Независимые переменные
                                    y=yyStd_test,   # Целевая переменная
                                    cv=3,       # Кол-во K-частей (Fold)
                                    scoring='r2'# Режим расчитываемой метрики
                                )

print("Значения метрики по каждому блоку cv:", scores_cross)
print("Усредненное значение метрики:", scores_cross.mean())
# Out:
# R2. Стандартизированные проверочные данные
# Значения метрики по каждому блоку cv: [0.39191541 0.38403534 0.37501   ]
# Усредненное значение метрики: 0.3836535846115556

# %%
print("RMSE. НЕ Стандартизированные проверочные данные")

mse_non_std  = metrics.mean_squared_error(y_test, y_pred)
rmse_non_std = np.sqrt(mse_non_std)

print ("RMSE: {:>9,.6f} (кв. корень из среднеквадратичной ошибки)".format(rmse_non_std))
# Out:
# RMSE. НЕ Стандартизированные проверочные данные
# RMSE: 16,180,731,140,802,082.000000 (кв. корень из среднеквадратичной ошибки)

# %%
print("RMSE. Стандартизированные проверочные данные")

mse_std  = metrics.mean_squared_error(yStd_test, y_pred_std)
rmse_std = np.sqrt(mse_std)

print ("RMSE: {:>9,.6f} (кв. корень из среднеквадратичной ошибки)".format(rmse_std))
# Out:
# RMSE. Стандартизированные проверочные данные
# RMSE:  0.780447 (кв. корень из среднеквадратичной ошибки)

# %% [markdown]
# ## Заключение о величине коридора изменений оценок моделей

# %% [markdown]
# # Итоговые, сводные результаты и выводы.

# %% [markdown]
# В ходе лабораторной работы, мы ознакомились и освоили работу с дополнительными методами машинного обучения для решения задачи регрессии библиотеки sklearn.

# %% [markdown]
# Так как наши данные уже были стандартизированы, нами было принято решение денормировать их для более качественного сравнения. Далее, была применена модель STDRegression для исследования влияния процесса стандартизации. Заметим, что стандартизированные данные показывают результаты на порядок качественнее, чем нестандартизированные

# %% [markdown]
# Были использованы такие качества для оценки точности модели, как: RMSE и R2.

# %% [markdown]
# Также обратим внимание, что если нет возможности стандартизировать данные, то линейная модель может показать себя лучше, чем применение STDRegression
